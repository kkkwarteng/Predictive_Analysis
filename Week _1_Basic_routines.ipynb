# %%
# Week 1: Let's try using Python 
# Import all libraries needed
# Pandas for data manupilation
# Numpy for statistics and numerial analysis
# Matplotlib.pyplot for plots and graphs
#Statsmodels.formula.api for linear regression

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
from statsmodels.stats.diagnostic import het_white
from statsmodels.compat import lzip 
import statsmodels.api as sm

# %%
# Import data using the file path name
data=pd.read_excel('C:/Users/malkii/Downloads/nls80.xls')
data.head()  # use to check the data are correctly uploaded
# Out:
#    wage  hours   iq  kww  educ  exper  tenure  age  married  black  south  \
# 0   769     40   93   35    12     11       2   31        1      0      0
# 1   808     50  119   41    18     11      16   37        1      0      0
# 2   825     40  108   46    14     11       9   33        1      0      0
# 3   650     40   96   32    12     13       7   32        1      0      0
# 4   562     40   74   27    11     14       5   34        1      0      0
#
#    urban  sibs brthord meduc feduc     lwage
# 0      1     1       2     8     8  6.645091
# 1      1     1       .    14    14  6.694562
# 2      1     1       2    14    14  6.715384
# 3      1     4       3    12    12  6.476973
# 4      1    10       6     6    11  6.331502

# %%
data.describe() # This reports key statistics for all the variables in the data.
# Out:
#               wage       hours          iq         kww        educ  \
# count   935.000000  935.000000  935.000000  935.000000  935.000000
# mean    957.945455   43.929412  101.282353   35.744385   13.468449
# std     404.360822    7.224256   15.052636    7.638788    2.196654
# min     115.000000   20.000000   50.000000   12.000000    9.000000
# 25%     669.000000   40.000000   92.000000   31.000000   12.000000
# 50%     905.000000   40.000000  102.000000   37.000000   12.000000
# 75%    1160.000000   48.000000  112.000000   41.000000   16.000000
# max    3078.000000   80.000000  145.000000   56.000000   18.000000
#
#             exper      tenure         age     married       black       south  \
# count  935.000000  935.000000  935.000000  935.000000  935.000000  935.000000
# mean    11.563636    7.234225   33.080214    0.893048    0.128342    0.341176
# std      4.374586    5.075206    3.107803    0.309217    0.334650    0.474358
# ...

# %%
# For specific variables, you can use the following expression. Each line reports a set of statistics
# the general expression is print("name of stat, variable of interest.statistic command")

print ("---------------------------------Some Key Statistics---------------------------")
print("Mean","","",data['wage'].mean(),data['educ'].mean(),data['hours'].mean())
print("Std","","", data['wage'].std(),data['educ'].std(), data['hours'].std())
print("Skewness",data['wage'].skew(),data['educ'].skew(), data['hours'].skew())
print("Kurtosis",data['wage'].kurtosis(),data['educ'].kurtosis(), data['hours'].kurtosis())

print ("------------------------------End of  Key Statistics------------------------")

# Generating log wage using a user defined codes. The log of wage is alread given.
# The aim is to learn some routines that can be added.
# Out:
# ---------------------------------Some Key Statistics---------------------------
# Mean   957.9454545454546 13.468449197860963 43.92941176470588
# Std   404.3608224739389 2.196653882081251 7.224255863405396
# Skewness 1.2011867939423562 0.5486765038398799 1.5961751935471453
# Kurtosis 2.7175817987969597 -0.7348626864555614 4.186640520128211
# ------------------------------End of  Key Statistics------------------------

# %%
# Generating log wage using a user defined codes. The log of wage is alread given.
# The aim is to learn some routines that can be added.


def Log(x):
        log_x=np.log(x)
        return log_x

data['logwage']=Log(data['wage'])

## End of the user defined code. Let's try it out

# %%
#Another way

lwage2=np.log(data['wage'])

# %%
# Histograms 

# Historgram and distribution of the data of interest

print ("---------------------------------Distributions of Key Variables---------------------------")

plt.figure(1)
plt.hist(data['wage'], 20, edgecolor='black', linewidth=1.2)
plt.xlabel('wage')
plt.ylabel('Density')
plt.title('Wage Distribution')
plt.show()
# Out:
# ---------------------------------Distributions of Key Variables---------------------------
